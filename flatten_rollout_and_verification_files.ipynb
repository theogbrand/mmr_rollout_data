# %%
import json
import os
import glob
from pathlib import Path
from typing import List, Dict, Any

def check_schema_consistency(jsonl_files: List[str]) -> bool:
    """Check if all JSONL files have identical schema."""
    if not jsonl_files:
        return True
    
    # Read first file to get reference schema
    with open(jsonl_files[0], 'r') as f:
        first_line = f.readline().strip()
        if not first_line:
            return True
        reference_schema = set(json.loads(first_line).keys())
    
    # Check all other files
    for file_path in jsonl_files[1:]:
        with open(file_path, 'r') as f:
            first_line = f.readline().strip()
            if not first_line:
                continue
            current_schema = set(json.loads(first_line).keys())
            if current_schema != reference_schema:
                print(f"Schema mismatch in {file_path}")
                print(f"Expected: {reference_schema}")
                print(f"Found: {current_schema}")
                return False
    
    return True

def flatten_jsonl_files(input_files: List[str], output_file: str) -> int:
    """Flatten multiple JSONL files into a single JSONL file."""
    total_lines = 0
    
    with open(output_file, 'w') as outfile:
        for file_path in input_files:
            print(f"Processing {file_path}...")
            with open(file_path, 'r') as infile:
                for line in infile:
                    line = line.strip()
                    if line:  # Skip empty lines
                        outfile.write(line + '\n')
                        total_lines += 1
    
    return total_lines

# %% [markdown]
# # For RAVEN, we need to add a "split" row for train/valid set (skip if already done)

# %%
# Found: {'question', 'subset_split', 'split', 'correct_answer', 'combined_image_path', 'steps_with_score', 'response', 'id'}
# Expected: {'question', 'subset_split', 'correct_answer', 'combined_image_path', 'steps_with_score', 'response', 'id'}

# %%
# /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single
import os

# Directory path
directory = "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine"

# List all files in the directory
try:
    files = os.listdir(directory)
    
    print(f"Files in {directory}:")
    print(f"Total files: {len(files)}")
    print("-" * 50)
    
    for i, filename in enumerate(sorted(files), 1):
        print(f"{i:3d}. {filename}")
        
except FileNotFoundError:
    print(f"Directory not found: {directory}")
except PermissionError:
    print(f"Permission denied accessing: {directory}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Files in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine:
# Total files: 7
# --------------------------------------------------
#   1. distribute_nine_train_raven_rollouts_0_1999_streaming.jsonl
#   2. distribute_nine_train_raven_rollouts_2000_3999_streaming.jsonl
#   3. distribute_nine_train_raven_rollouts_4000_5999_streaming.jsonl
#   4. distribute_nine_train_raven_rollouts_6000_7999_streaming.jsonl
#   5. distribute_nine_train_raven_rollouts_8000_9999_streaming.jsonl
#   6. distribute_nine_validation_raven_rollouts_0_4999_streaming.jsonl
#   7. distribute_nine_validation_raven_rollouts_5000_9999_streaming.jsonl

# %%
import json
import os
from typing import List, Dict, Any

def add_split_column_to_jsonl_files(file_paths: List[str], split_value: str, output_dir: str = None, backup: bool = True) -> None:
    """
    Add a 'split' column to JSONL files.
    
    Args:
        file_paths: List of JSONL file paths to process
        split_value: The value to assign to the 'split' column for all rows
        output_dir: Directory to save modified files (if None, overwrites original)
        backup: Whether to create backup files before modification (only if output_dir is None)
    """
    
    for file_path in file_paths:
        if not os.path.exists(file_path):
            print(f"Warning: File not found: {file_path}")
            continue
            
        print(f"Processing {file_path}...")
        
        # Determine output file path
        if output_dir:
            # Create output directory if it doesn't exist
            os.makedirs(output_dir, exist_ok=True)
            # Use original filename in output directory
            filename = os.path.basename(file_path)
            output_file_path = os.path.join(output_dir, filename)
        else:
            # Overwrite original file
            output_file_path = file_path
            # Create backup if requested
            if backup:
                backup_path = file_path + ".backup"
                os.rename(file_path, backup_path)
                source_path = backup_path
            else:
                source_path = file_path
        
        # Read, modify, and write
        modified_lines = []
        source_path = file_path if output_dir else source_path
        
        with open(source_path, 'r') as infile:
            for line_num, line in enumerate(infile, 1):
                line = line.strip()
                if line:  # Skip empty lines
                    try:
                        data = json.loads(line)
                        # Add the split column
                        data['split'] = split_value
                        modified_lines.append(json.dumps(data))
                    except json.JSONDecodeError as e:
                        print(f"Error parsing line {line_num} in {file_path}: {e}")
                        continue
        
        # Write modified data to output file
        with open(output_file_path, 'w') as outfile:
            for line in modified_lines:
                outfile.write(line + '\n')
        
        if output_dir:
            print(f"Added 'split' column with value '{split_value}' to {len(modified_lines)} rows in {output_file_path}")
        else:
            print(f"Added 'split' column with value '{split_value}' to {len(modified_lines)} rows in {file_path}")

# # Example usage:
# # Specify your JSONL file paths
# jsonl_files = [
#     "./raw_rollouts/rollouts_only/RAVEN/left_center_single_right_center_single_train/left_center_single_right_center_single_train_raven_rollouts_6859_8000_streaming.jsonl",
#     "./raw_rollouts/rollouts_only/RAVEN/left_center_single_right_center_single_train/left_center_single_right_center_single_train_raven_rollouts_3430_4572_streaming.jsonl",
#     # Add more file paths as needed
# ]

# # Specify the split value
# split_value = "train"  # or "validation", "test", etc.

# # Option 1: Create new files in output directory
# output_directory = "./modified_jsonl_files"
# add_split_column_to_jsonl_files(jsonl_files, split_value, output_dir=output_directory)

# # Option 2: Overwrite original files (with backup)
# # add_split_column_to_jsonl_files(jsonl_files, split_value, backup=True)

# %%
# Process different groups of files with different split values
file_groups = {
#     "train": [
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_0_1999_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_2000_3332_streaming.jsonl", 
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_3333_4665_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_4666_5998_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_5999_7331_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_7332_8664_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_train_raven_rollouts_8665_9995_streaming.jsonl"
# ],
# "train": [
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_train_raven_rollouts_0_1999_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_train_raven_rollouts_2000_3999_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_train_raven_rollouts_4000_5999_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_train_raven_rollouts_6000_7999_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_train_raven_rollouts_8000_9999_streaming.jsonl"
# ],
"train": [
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_0_1999_streaming.jsonl",
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_2000_3999_streaming.jsonl",
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_4000_5999_streaming.jsonl",
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_6000_7999_streaming.jsonl",
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_8000_9999_streaming.jsonl"
],
    # "validation":  [
    # "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_validation_raven_rollouts_5000_9999.jsonl",
    # "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/center_single/center_single_validation_raven_rollouts__validation_0_4999.jsonl"
#     "validation":  [
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_validation_raven_rollouts_0_4999_streaming.jsonl",
#     "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_four/distribute_four_validation_raven_rollouts_5000_9999_streaming.jsonl"
# ]
    "validation":   [
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_validation_raven_rollouts_0_4999_streaming.jsonl",
    "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_validation_raven_rollouts_5000_9999_streaming.jsonl"
]
}

# Process each group
for split_val, files in file_groups.items():
    print(f"\n=== Processing {split_val} files ===")
    add_split_column_to_jsonl_files(files, split_val, output_dir=f"/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new", backup=False)
# Out:
# === Processing train files ===
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_0_1999_streaming.jsonl...
# Added 'split' column with value 'train' to 4771 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_train_raven_rollouts_0_1999_streaming.jsonl
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_2000_3999_streaming.jsonl...
# Added 'split' column with value 'train' to 4770 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_train_raven_rollouts_2000_3999_streaming.jsonl
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_4000_5999_streaming.jsonl...
# Added 'split' column with value 'train' to 4770 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_train_raven_rollouts_4000_5999_streaming.jsonl
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_6000_7999_streaming.jsonl...
# Added 'split' column with value 'train' to 4767 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_train_raven_rollouts_6000_7999_streaming.jsonl
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_train_raven_rollouts_8000_9999_streaming.jsonl...
# Added 'split' column with value 'train' to 4689 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_train_raven_rollouts_8000_9999_streaming.jsonl
#
# === Processing validation files ===
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_validation_raven_rollouts_0_4999_streaming.jsonl...
# Added 'split' column with value 'validation' to 3970 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_validation_raven_rollouts_0_4999_streaming.jsonl
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN/distribute_nine/distribute_nine_validation_raven_rollouts_5000_9999_streaming.jsonl...
# Added 'split' column with value 'validation' to 3968 rows in /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/rollouts_only/RAVEN_new/distribute_nine_validation_raven_rollouts_5000_9999_streaming.jsonl

# %% [markdown]
# # now we flatten rollouts first

# %%
# splits = ["RAVEN_new"] # renamed renamed to RAVEN, RAVEN_new includes the new split column added in above step
# splits = ["AI2D", "CLEVR_10K", "RAVEN"]

splits = ["vqav2"] # TODO: Copy from the soft_esimtation/final_rollout_output "subfolders" into the ./rollouts_only folder 
output_dir = "/mnt/fast10/brandon/mmr_rollout_data/flattened_rollout_files"

# Process each split
for split in splits:
    print(f"\n=== Processing split: {split} ===")
    
    # Find all JSONL files in the split directory
    split_dir = f"./raw_rollouts/rollouts_only/{split}"
    if split == "RAVEN":
        jsonl_pattern = os.path.join(split_dir, "**", "*.jsonl")
        jsonl_files = glob.glob(jsonl_pattern, recursive=True)
    else:
        jsonl_pattern = os.path.join(split_dir, "*.jsonl")
        jsonl_files = glob.glob(jsonl_pattern)
    
    if not jsonl_files:
        print(f"No JSONL files found in {split_dir}")
        continue
    
    print(f"Found {len(jsonl_files)} JSONL files:")
    for file_path in jsonl_files:
        print(f"  - {file_path}")
    
    # Check schema consistency
    print(f"\nChecking schema consistency...")
    if not check_schema_consistency(jsonl_files):
        print(f"ERROR: Schema mismatch detected in {split}. Skipping flattening.")
        continue
    
    print("Schema check passed!")
 
    # Flatten files
    output_file = f"{output_dir}/{split}_flattened.jsonl"
    print(f"Flattening to {output_file}...")
    
    total_lines = flatten_jsonl_files(jsonl_files, output_file)
    print(f"Successfully flattened {total_lines} lines to {output_file}")

print("\n=== All splits processed ===")
# Out:
# === Processing split: vqav2 ===
# Found 5 JSONL files:
#   - ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_1_800_streaming.jsonl
#   - ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_2401_3200_streaming.jsonl
#   - ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_3201_4000_streaming.jsonl
#   - ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_801_1600_streaming.jsonl
#   - ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_1601_2400_streaming.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_rollout_files/vqav2_flattened.jsonl...
# Processing ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_1_800_streaming.jsonl...
# Processing ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_2401_3200_streaming.jsonl...
# Processing ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_3201_4000_streaming.jsonl...
# Processing ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_801_1600_streaming.jsonl...
# Processing ./raw_rollouts/rollouts_only/vqav2/vqav2_run1_int_only_4K_v1_subset_raven_rollouts_1601_2400_streaming.jsonl...
# Successfully flattened 23947 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_rollout_files/vqav2_flattened.jsonl
#
# === All splits processed ===

# %%
# Verify the flattened files
for split in splits:
    output_file = f"{output_dir}/{split}_flattened.jsonl"
    if os.path.exists(output_file):
        with open(output_file, 'r') as f:
            line_count = sum(1 for line in f if line.strip())
        print(f"{split}_flattened.jsonl: {line_count} lines")
# Out:
# vqav2_flattened.jsonl: 23947 lines

# %% [markdown]
# ## Flatten Verification Query Files

# %% [markdown]
# ## for typical split where dataset name and split is the same because no additional splits within the dataset. BUT RAVEN/CLEVR is different (see below)

# %%
import os
import glob

# Configuration
dataset_name = "vqav2" # no need for RAVEN_new because that is only for appending the split columns to the rollout files

models = ["gpt-4.1-mini", "gpt-4.1-nano", "o4-mini"]
output_dir = "/mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process each model
for model in models:
    print(f"\n=== Processing model: {model} ===")
    
    # Find all JSONL files in the verification batches directory
    verification_dir = f"/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/{dataset_name}/verification/verification_pipeline_outputs/{model}/{dataset_name}/verification_batches/"
    
    jsonl_pattern = os.path.join(verification_dir, "*.jsonl")
    jsonl_files = glob.glob(jsonl_pattern)
    
    if not jsonl_files:
        print(f"No JSONL files found in {verification_dir}")
        continue
    
    print(f"Found {len(jsonl_files)} JSONL files:")
    for file_path in jsonl_files:
        print(f"  - {file_path}")
    
    # Check schema consistency
    print(f"\nChecking schema consistency...")
    if not check_schema_consistency(jsonl_files):
        print(f"ERROR: Schema mismatch detected in {model}. Skipping flattening.")
        continue
    
    print("Schema check passed!")
 
    # Flatten files
    output_file = f"{output_dir}/{dataset_name}_{model}_verification_query_flattened.jsonl"
    print(f"Flattening to {output_file}...")
    
    total_lines = flatten_jsonl_files(jsonl_files, output_file)
    print(f"Successfully flattened {total_lines} lines to {output_file}")

print("\n=== All models processed ===")
# Out:
# === Processing model: gpt-4.1-mini ===
# Found 13 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0012.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0013.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0008.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0010.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0009.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0007.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0011.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/vqav2_gpt-4.1-mini_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0012.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0013.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0008.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0010.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0009.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0007.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0011.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/verification_batches/batch_0006.jsonl...
# Successfully flattened 23947 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/vqav2_gpt-4.1-mini_verification_query_flattened.jsonl
#
# === Processing model: gpt-4.1-nano ===
# Found 14 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0012.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0013.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0008.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0010.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0014.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0009.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0007.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0011.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/vqav2_gpt-4.1-nano_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0012.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0013.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0008.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0010.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0014.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0009.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0007.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0011.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/verification_batches/batch_0006.jsonl...
# Successfully flattened 23947 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/vqav2_gpt-4.1-nano_verification_query_flattened.jsonl
#
# === Processing model: o4-mini ===
# Found 11 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0008.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0010.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0009.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0007.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0011.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/vqav2_o4-mini_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0008.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0010.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0009.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0007.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0011.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/verification_batches/batch_0006.jsonl...
# Successfully flattened 23947 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/vqav2_o4-mini_verification_query_flattened.jsonl
#
# === All models processed ===

# %% [markdown]
# ## Duo Structure

# %%
import os
import glob

dataset_mapping = {
    "RAVEN": ["center_single", "distribute_four", "distribute_nine", "in_center_single_out_center_single_train", "in_distribute_four_out_center_single_train", "left_center_single_right_center_single_train", "up_center_single_down_center_single_train" ],
    "CLEVR": ["CLEVR_first_5k", "CLEVR_second_5k"],
    "dvqa": ["dvqa_first_5k", "dvqa_second_5k", "dvqa_third_5k"]
}

# Configuration

models = ["gpt-4.1-mini", "gpt-4.1-nano", "o4-mini"]
output_dir = "/mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files"

dataset_name = "dvqa" # TODO: fill in dataset_mapping and dataset_name processing

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process each model
for model in models:
    for dataset_pattern in dataset_mapping[dataset_name]: # edit accordingly
        print(f"\n=== Processing model: {model} and dataset pattern: {dataset_pattern} ===")
        
        # Find all JSONL files in the verification batches directory
        verification_dir = f"/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/{dataset_name}/verification/verification_pipeline_outputs/{model}/{dataset_pattern}/verification_batches/"
        
        jsonl_pattern = os.path.join(verification_dir, "*.jsonl")
        jsonl_files = glob.glob(jsonl_pattern)
        
        if not jsonl_files:
            print(f"No JSONL files found in {verification_dir}")
            continue
        
        print(f"Found {len(jsonl_files)} JSONL files:")
        for file_path in jsonl_files:
            print(f"  - {file_path}")
        
        # Check schema consistency
        print(f"\nChecking schema consistency...")
        if not check_schema_consistency(jsonl_files):
            print(f"ERROR: Schema mismatch detected in {model}. Skipping flattening.")
            continue
        
        print("Schema check passed!")
    
        # Flatten files
        output_file = f"{output_dir}/{dataset_name}_{model}_{dataset_pattern}_verification_query_flattened.jsonl"
        print(f"Flattening to {output_file}...")
        
        total_lines = flatten_jsonl_files(jsonl_files, output_file)
        print(f"Successfully flattened {total_lines} lines to {output_file}")

print("\n=== All models processed ===")
# Out:
# === Processing model: gpt-4.1-mini and dataset pattern: dvqa_first_5k ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-mini_dvqa_first_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/verification_batches/batch_0006.jsonl...
# Successfully flattened 32735 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-mini_dvqa_first_5k_verification_query_flattened.jsonl
#
# === Processing model: gpt-4.1-mini and dataset pattern: dvqa_second_5k ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0001.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-mini_dvqa_second_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/verification_batches/batch_0001.jsonl...
# Successfully flattened 28644 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-mini_dvqa_second_5k_verification_query_flattened.jsonl
#
# === Processing model: gpt-4.1-mini and dataset pattern: dvqa_third_5k ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0001.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-mini_dvqa_third_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/verification_batches/batch_0001.jsonl...
# Successfully flattened 28620 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-mini_dvqa_third_5k_verification_query_flattened.jsonl
#
# === Processing model: gpt-4.1-nano and dataset pattern: dvqa_first_5k ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-nano_dvqa_first_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/verification_batches/batch_0006.jsonl...
# Successfully flattened 32735 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-nano_dvqa_first_5k_verification_query_flattened.jsonl
#
# === Processing model: gpt-4.1-nano and dataset pattern: dvqa_second_5k ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0001.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-nano_dvqa_second_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/verification_batches/batch_0001.jsonl...
# Successfully flattened 28644 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-nano_dvqa_second_5k_verification_query_flattened.jsonl
#
# === Processing model: gpt-4.1-nano and dataset pattern: dvqa_third_5k ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0001.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-nano_dvqa_third_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/verification_batches/batch_0001.jsonl...
# Successfully flattened 28620 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_gpt-4.1-nano_dvqa_third_5k_verification_query_flattened.jsonl
#
# === Processing model: o4-mini and dataset pattern: dvqa_first_5k ===
# Found 7 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0007.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_o4-mini_dvqa_first_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0007.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/verification_batches/batch_0006.jsonl...
# Successfully flattened 32735 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_o4-mini_dvqa_first_5k_verification_query_flattened.jsonl
#
# === Processing model: o4-mini and dataset pattern: dvqa_second_5k ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_o4-mini_dvqa_second_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/verification_batches/batch_0006.jsonl...
# Successfully flattened 28644 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_o4-mini_dvqa_second_5k_verification_query_flattened.jsonl
#
# === Processing model: o4-mini and dataset pattern: dvqa_third_5k ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0005.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0002.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0004.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0003.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0001.jsonl
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0006.jsonl
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_o4-mini_dvqa_third_5k_verification_query_flattened.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0005.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0002.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0004.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0003.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0001.jsonl...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/verification_batches/batch_0006.jsonl...
# Successfully flattened 28620 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/dvqa_o4-mini_dvqa_third_5k_verification_query_flattened.jsonl
#
# === All models processed ===

# %% [markdown]
# # Flatten verification JSON (result) files

# %%
def check_schema_consistency_json(json_files: List[str]) -> bool:
    """Check if all JSON files have identical schema."""
    if not json_files:
        return True
    
    # Read first file to get reference schema
    with open(json_files[0], 'r') as f:
        data = json.load(f)
        if isinstance(data, list) and len(data) > 0:
            reference_schema = set(data[0].keys())
        # elif isinstance(data, dict):
        #     reference_schema = set(data.keys())
        else:
            raise ValueError(f"Invalid data type in {json_files[0]}")
    
    # Check all other files
    for file_path in json_files[1:]:
        with open(file_path, 'r') as f:
            data = json.load(f)
            if isinstance(data, list) and len(data) > 0:
                current_schema = set(data[0].keys())
            # elif isinstance(data, dict):
            #     current_schema = set(data.keys())
            else:
                raise ValueError(f"Invalid data type in {file_path}")
            if current_schema != reference_schema:
                print(f"Schema mismatch in {file_path}")
                print(f"Expected: {reference_schema}")
                print(f"Found: {current_schema}")
                raise ValueError(f"Schema mismatch in {file_path}")
    
    return True

def flatten_json_files(input_files: List[str], output_file: str) -> int:
    """Flatten multiple JSON files into a single JSON file."""
    all_data = []
    
    for file_path in input_files:
        print(f"Processing {file_path}...")
        with open(file_path, 'r') as f:
            data = json.load(f)
            if isinstance(data, list):
                all_data.extend(data)
            else:
                all_data.append(data)
    
    with open(output_file, 'w') as f:
        json.dump(all_data, f, indent=2)
    
    return len(all_data)

# %% [markdown]
# ## Like for query files above, two cases. Firstly for flat single structure. Then for double structure (below)

# %%
import os
import glob

# Configuration
dataset_name = "vqav2"
models = ["gpt-4.1-mini", "gpt-4.1-nano", "o4-mini"]
output_dir = "/mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process each model
for model in models:
    print(f"\n=== Processing model: {model} ===")
    
    # Find all JSONL files in the verification batches directory
    verification_dir = f"/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/{dataset_name}/verification/verification_pipeline_outputs/{model}/{dataset_name}"
    
    jsonl_pattern = os.path.join(verification_dir, "batch_*_verification_results.json")
    jsonl_files = glob.glob(jsonl_pattern)
    
    if not jsonl_files:
        print(f"No JSONL files found in {verification_dir}")
        continue
    
    print(f"Found {len(jsonl_files)} JSONL files:")
    for file_path in jsonl_files:
        print(f"  - {file_path}")
    
    # Check schema consistency
    print(f"\nChecking schema consistency...")
    if not check_schema_consistency_json(jsonl_files):
        print(f"ERROR: Schema mismatch detected in {model}. Skipping flattening.")
        continue
    
    print("Schema check passed!")
 
    # Flatten files
    output_file = f"{output_dir}/{dataset_name}_{model}_verification_result_flattened.json"
    print(f"Flattening to {output_file}...")
    
    total_lines = flatten_json_files(jsonl_files, output_file)
    print(f"Successfully flattened {total_lines} lines to {output_file}")

print("\n=== All models processed ===")
# TO NOTE: should take significantly faster than flattening query because only text involved here but image involved in query
# Out:
# === Processing model: gpt-4.1-mini ===
# Found 13 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0008_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0007_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0013_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0012_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0009_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0010_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0011_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/vqav2_gpt-4.1-mini_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0008_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0007_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0013_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0012_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0009_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0010_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0011_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-mini/vqav2/batch_0001_verification_results.json...
# Successfully flattened 23929 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/vqav2_gpt-4.1-mini_verification_result_flattened.json
#
# === Processing model: gpt-4.1-nano ===
# Found 14 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0008_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0007_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0013_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0012_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0009_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0010_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0014_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0011_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/vqav2_gpt-4.1-nano_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0008_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0007_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0013_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0012_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0009_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0010_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0014_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0011_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/gpt-4.1-nano/vqav2/batch_0001_verification_results.json...
# Successfully flattened 23937 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/vqav2_gpt-4.1-nano_verification_result_flattened.json
#
# === Processing model: o4-mini ===
# Found 11 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0008_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0007_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0009_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0010_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0011_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/vqav2_o4-mini_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0008_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0007_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0009_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0010_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0011_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/vqav2/verification/verification_pipeline_outputs/o4-mini/vqav2/batch_0001_verification_results.json...
# Successfully flattened 23934 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/vqav2_o4-mini_verification_result_flattened.json
#
# === All models processed ===

# %% [markdown]
# ## Double Structure

# %%
import os
import glob

dataset_mapping = {
    "RAVEN": ["center_single", "distribute_four", "distribute_nine", "in_center_single_out_center_single_train", "in_distribute_four_out_center_single_train", "left_center_single_right_center_single_train", "up_center_single_down_center_single_train" ],
    "CLEVR": ["CLEVR_first_5k", "CLEVR_second_5k"],
    "dvqa": ["dvqa_first_5k", "dvqa_second_5k", "dvqa_third_5k"]
}

dataset_name = "dvqa" # TODO: fill in dataset_mapping and dataset_name processing

models = ["gpt-4.1-mini", "gpt-4.1-nano", "o4-mini"]

output_dir = "/mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process each model
for model in models:
    for dataset_pattern in dataset_mapping[dataset_name]: # edit accordingly
        print(f"\n=== Processing model: {model} ===")
        
        # Find all JSON files in the verification batches directory
        verification_dir = f"/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/{dataset_name}/verification/verification_pipeline_outputs/{model}/{dataset_pattern}"
        
        jsonl_pattern = os.path.join(verification_dir, "batch_*_verification_results.json")
        jsonl_files = glob.glob(jsonl_pattern)
        
        if not jsonl_files:
            print(f"No JSONL files found in {verification_dir}")
            continue
        
        print(f"Found {len(jsonl_files)} JSONL files:")
        for file_path in jsonl_files:
            print(f"  - {file_path}")
        
        # Check schema consistency
        print(f"\nChecking schema consistency...")
        if not check_schema_consistency_json(jsonl_files):
            print(f"ERROR: Schema mismatch detected in {model}. Skipping flattening.")
            continue
        
        print("Schema check passed!")
    
        # Flatten files
        output_file = f"{output_dir}/{dataset_name}_{model}_{dataset_pattern}_verification_result_flattened.json"
        print(f"Flattening to {output_file}...")
        
        total_lines = flatten_json_files(jsonl_files, output_file)
        print(f"Successfully flattened {total_lines} lines to {output_file}")

print("\n=== All models processed ===")
# Out:
# === Processing model: gpt-4.1-mini ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-mini_dvqa_first_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_first_5k/batch_0001_verification_results.json...
# Successfully flattened 32735 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-mini_dvqa_first_5k_verification_result_flattened.json
#
# === Processing model: gpt-4.1-mini ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-mini_dvqa_second_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_second_5k/batch_0001_verification_results.json...
# Successfully flattened 28644 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-mini_dvqa_second_5k_verification_result_flattened.json
#
# === Processing model: gpt-4.1-mini ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-mini_dvqa_third_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-mini/dvqa_third_5k/batch_0001_verification_results.json...
# Successfully flattened 28620 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-mini_dvqa_third_5k_verification_result_flattened.json
#
# === Processing model: gpt-4.1-nano ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-nano_dvqa_first_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_first_5k/batch_0001_verification_results.json...
# Successfully flattened 32735 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-nano_dvqa_first_5k_verification_result_flattened.json
#
# === Processing model: gpt-4.1-nano ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-nano_dvqa_second_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_second_5k/batch_0001_verification_results.json...
# Successfully flattened 28644 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-nano_dvqa_second_5k_verification_result_flattened.json
#
# === Processing model: gpt-4.1-nano ===
# Found 5 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-nano_dvqa_third_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/gpt-4.1-nano/dvqa_third_5k/batch_0001_verification_results.json...
# Successfully flattened 28620 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_gpt-4.1-nano_dvqa_third_5k_verification_result_flattened.json
#
# === Processing model: o4-mini ===
# Found 7 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0007_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_o4-mini_dvqa_first_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0007_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_first_5k/batch_0001_verification_results.json...
# Successfully flattened 32735 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_o4-mini_dvqa_first_5k_verification_result_flattened.json
#
# === Processing model: o4-mini ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_o4-mini_dvqa_second_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_second_5k/batch_0001_verification_results.json...
# Successfully flattened 28644 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_o4-mini_dvqa_second_5k_verification_result_flattened.json
#
# === Processing model: o4-mini ===
# Found 6 JSONL files:
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0005_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0003_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0004_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0002_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0006_verification_results.json
#   - /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0001_verification_results.json
#
# Checking schema consistency...
# Schema check passed!
# Flattening to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_o4-mini_dvqa_third_5k_verification_result_flattened.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0005_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0003_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0004_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0002_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0006_verification_results.json...
# Processing /mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/dvqa/verification/verification_pipeline_outputs/o4-mini/dvqa_third_5k/batch_0001_verification_results.json...
# Successfully flattened 28586 lines to /mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/dvqa_o4-mini_dvqa_third_5k_verification_result_flattened.json
#
# === All models processed ===

# %% [markdown]
# # Explore Files

# %%
# load first row of JSONL file from this path with keys

import json

# Load first row of the JSONL file
file_path = "/mnt/fast10/brandon/mmr_rollout_data/raw_rollouts/soft_estimation/AI2D/verification/verification_pipeline_outputs/o4-mini/AI2D/verification_batches/batch_0001.jsonl"

with open(file_path, 'r') as f:
    first_line = f.readline().strip()
    if first_line:
        first_row = json.loads(first_line)
        print("Keys in first row:")
        for key in first_row.keys():
            print(f"  - {key}")
        print("First row values:")
        for key, value in first_row.items():
            if key != "body":
                print(f"  {key}: {value}")
            else:
                print(f"  {key}: {type(value)}")
                print(f"  {key}: {value.keys()}")
                
                print(f"  Messages in Body Key: {value['messages'][0]['content'][0]["text"]}")
        print(first_row["custom_id"])
        print(f"\nTotal keys: {len(first_row.keys())}")
    else:
        print("File is empty")

# Count rows in JSONL file (excluding header)
# with open(file_path, 'r') as f:
#     # Skip first line (header) and count remaining lines
#     lines = f.readlines()
#     if lines:
#         # Remove header and count non-empty lines
#         data_lines = [line for line in lines if line.strip()]
#         row_count = len(data_lines)
#         print(f"Number of data rows (excluding header): {row_count}")
#     else:
#         print("File is empty")
# Out:
# Keys in first row:
#   - custom_id
#   - method
#   - url
#   - body
# First row values:
#   custom_id: 19ce6132-6781-4c96-adf5-f6f5da514761
#   method: POST
#   url: /chat/completions
#   body: <class 'dict'>
#   body: dict_keys(['model', 'messages', 'max_completion_tokens'])
#   Messages in Body Key: I will provide a visual reasoning problem along with a solution. They will be formatted as follows, where m and n need not be equal:
#
# ```
# [Visual Reasoning Problem]
#
#  <visual_reasoning_problem>
#  ...(visual reasoning problem)...
# </visual_reasoning_problem>
#
# [Solution]
#
# <solution>
# [Visual Elements]
# <step_1>
# ...(Step 1 of step-by-step visual elements perception)...
# </step_1>
# <step_2>
# ...(Step 2 of step-by-step visual elements perception)...
# </step_2>
# ...
# <step_m>
# ...(Step m of step-by-step visual elements perception)...
# </step_m>
#
# [Reasoning]
# <step_1>
# ...(Step 1 of step-by-step reasoning)...
# </step_1>
# <step_2>
# ...(Step 2 of step-by-step reasoning)...
# </step_2>
# ...
# <step_n>
# ...(Step n of step-by-step reasoning)...
# </step_n>
#
# <correct_answer>
# ...(The correct answer to the visual reasoning problem)...
# </correct_answer>
# </solution>
# ```
#
# Your task is to review each paragraph of the solution in sequence, analyzing, verifying, and critiquing the visual elements perception and reasoning in detail. You need to provide the analyses and the conclusion in the following format:
#
# [Visual Elements]
# <analysis_1>
# ...(analysis of step 1)...
# </analysis_1>
#
# ...
#
# <analysis_m>
# ...(analysis of step m)...
# </analysis_m>
#
# [Reasoning]
# <analysis_1>
# ...(analysis of step 1)...
# </analysis_1>
#
# ...
#
# <analysis_n>
# ...(analysis of step n)...
# </analysis_n>
#
# <conclusion>
# Correct/Incorrect
# </conclusion>
#
# * When you analyze each step, you should use proper logical or perceptual verification as appropriate, or reflection to indicate whether it is logically and perceptually valid. Please carefully go through this process.
#
# * Each analysis should:
# - Check if the described pattern/rule is actually present
# - Verify the logical consistency of the step
# - Confirm that conclusions follow from observations
#
# * If an error is detected in any step, you should describe the nature and cause of the error in detail, and suggest how to correct the error or the correct approach.
#
# * When the step is found to contain an error, stop further analysis of subsequent steps (as they may depend on the identified error) and directly provide the conclusion of "Incorrect" in the <conclusion> tag.
#
# * Only material reasoning or perception errors should trigger the early termination of the analysis.
#
# * For instance, given a solution of five steps, if an error is found in the third step, you should reply in the following format:
#
# <analysis_1>
# ...(analysis of step 1)...
# </analysis_1>
#
# <analysis_2>
# ...(analysis of step 2)...
# </analysis_2>
#
# <analysis_3>
# ...(analysis of step 3; since an error is found here, also provide detailed critique and correction guideline)...
# </analysis_3>
#
# <conclusion>
# Incorrect
# </conclusion>
#
# * Note that the analyses of steps 4 and 5 is skipped as step 3 has been found to contain an error.
#
# ------------------------------------------------------------
#
# The following is the visual reasoning problem and its corresponding solution, for you to review and verify:
#
# [Visual Reasoning Problem]
#  <visual_reasoning_problem>
# You are an advanced visual reasoning AI specialized in analyzing images for the Visual Question Answering (VQA) task. Your objective is to examine images containing various objects, scenes, geometric shapes, diagram elements, and potentially text or numbers, and reason about processes or changes, and answer questions about their attributes, relationships, and spatial arrangements.
#
# I will provide you with:
#
# 1. An image containing science diagrams
# 2. A question about the contents of the image
#
# Here is the question you need to answer:
#
# <question>
# What type of fly is depicted in the diagram at letter A?
# Stable
# Horn
# Face
# House
# Please answer the question based on the options mentioned before.
# </question>
#
# Please follow these steps to complete the task:
#
# 1. Carefully examine the image, paying attention to:
#    - Objects and scenes present
#    - Geometric shapes (if any)
#    - Attributes of each element (color, size, material, texture, etc.)
#    - Spatial relationships between elements
#    - Any text or numbers visible in the image (read and interpret these carefully)
#
# 2. Analyze the question to identify the type of reasoning required (e.g., counting, existence check, comparison, attribute query, or relationship assessment).
#
# 3. Conduct a thorough visual analysis of the image in relation to the question, focusing on relevant elements and attributes.
#
# 4. Formulate your answer based on your analysis.
#
# 5. Present your final answer as a single string in a LaTeX-formatted box using this format:
#    <correct_answer>
#    $\boxed{Your answer here}$
#    </correct_answer>
#
# Your task is to:
# - Under the [Visual Elements] section, list out all relevant visual elements step-by-step that relate to answering the question. Be thorough but concise. Wrap each step in <step_1>, <step_2>, ... tags.
# - Under the [Reasoning] section, explain your step-by-step reasoning process. This should include your analysis, interpretation, and how you arrived at the answer. Provide a clear justification of how you derived the answer from the data presented. Wrap each step in <step_1>, <step_2>, ... tags.
# - Present your final answer using the LaTeX-formatted box in `<correct_answer>` tags.
#
# It is crucial that your solution contains these sections in the exact format described below:
#
# ```
# [Visual Elements]
# <step_1>
# ...(Step 1 of step-by-step perception)...
# </step_1>
# <step_2>
# ...(Step 2 of step-by-step perception)...
# </step_2>
# ...
# <step_n>
# ...(Step n of step-by-step perception)...
# </step_n>
#
# [Reasoning]
# <step_1>
# ...(Step 1 of step-by-step reasoning)...
# </step_1>
# <step_2>
# ...(Step 2 of step-by-step reasoning)...
# </step_2>
# ...
# <step_m>
# ...(Step m of step-by-step reasoning)...
# </step_m>
#
# <correct_answer>
# $\boxed{Your answer here}$
# </correct_answer>
# ```
#
# Remember to:
# - Provide only a single string answer in the <correct_answer> section using the $\boxed{string_answer}$ format, and no other text or commentary.
#  </visual_reasoning_problem>
#
# [Solution]
# <solution>
# [Visual Elements]
# <step_1>
# There are four flies depicted, each labeled with a blue box and a white letter: A, B, C, D.
# </step_1>
# <step_2>
# The fly labeled "A" is shown at the far left of the image.
# </step_2>
# <step_3>
# The flies differ in body shape, wing shape, size, and other morphological features.
# </step_3>
# <step_4>
# The names of possible fly types given in the question are: Stable, Horn, Face, and House.
# </step_4>
# <step_5>
# The fly at position “A” shows characteristics commonly associated with the house fly: size, shape, and wing conformation.
# </step_5>
#
# [Reasoning]
# <step_1>
# The task is to identify the type of fly represented by the diagram at letter A, given four possible options.
# </step_1>
# <step_2>
# By comparing the appearance of the fly at A to common diagrams and references for Stable, Horn, Face, and House flies:
# - Stable fly: More robust thorax, prominent proboscis.
# - Horn fly: Usually more compact.
# - Face fly: Similar to house fly but with slightly different head/eye features.
# - House fly: Recognizable, classic fly form, common representation.
# </step_2>
# <step_3>
# The fly at position A has characteristics of the common house fly—medium size, clear vein patterns on the wings, and overall familiar structure found in educational diagrams for Musca domestica (house fly).
# </step_3>
# <step_4>
# Cross-referencing further, the house fly is typically presented in position A in such labeled diagrams, with the other flies placed in other positions for comparison.
# </step_4>
# <step_5>
# Therefore, the answer is “House”.
# </step_5>
#
# <correct_answer>
# $\boxed{House}$
# </correct_answer>
# </solution>
#
# Remember:
# - The <conclusion> tag must contain either Correct or Incorrect, with no additional text or punctuation.
# 19ce6132-6781-4c96-adf5-f6f5da514761
#
# Total keys: 4

# %%
import json

# Load first item from the JSON file (does not work for JSONL)
file_path = "/mnt/fast10/brandon/mmr_rollout_data/flattened_verification_result_files/AI2D_o4-mini_verification_flattened.json"
# empty verification values means likely the verification returned an error
with open(file_path, 'r') as f:
    data = json.load(f)
    
    if isinstance(data, list) and len(data) > 0:
        first_item = data[0]
        print("Keys in first item:")
        for key in first_item.keys():
            print(f"  - {key}")
        print(f"\nTotal keys: {len(first_item.keys())}")
    elif isinstance(data, dict):
        print("Keys in JSON object:")
        for key in data.keys():
            print(f"  - {key}")
        print(f"\nTotal keys: {len(data.keys())}")
    else:
        print("File is empty or not a list/dict")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 7
#       4 file_path = "/mnt/fast10/brandon/mmr_rollout_data/flattened_verification_query_files/AI2D_o4-mini_verification_flattened.jsonl"
#       6 with open(file_path, 'r') as f:
# ----> 7     data = json.load(f)
#       9     if isinstance(data, list) and len(data) > 0:
#      10         first_item = data[0]
#
# File ~/.conda/envs/mmr_processing/lib/python3.12/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/.conda/envs/mmr_processing/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/.conda/envs/mmr_processing/lib/python3.12/json/decoder.py:341, in JSONDecoder.decode(self, s, _w)
#     339 end = _w(s, end).end()
#     340 if end != len(s):
# --> 341     raise JSONDecodeError("Extra data", s, end)
#     342 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 92363)

# %%
# Find and print the item with the specific custom_id
target_custom_id = "203288af-ef39-41da-bff6-5184ad83b951"

with open(file_path, 'r') as f:
    data = json.load(f)
    
    if isinstance(data, list):
        # Search through the list for the target custom_id
        target_item = None
        for item in data:
            if item.get("custom_id") == target_custom_id:
                target_item = item
                break
        
        if target_item:
            print(f"Found item with custom_id: {target_custom_id}")
            print("Item contents:")
            print(json.dumps(target_item, indent=2))
        else:
            print(f"No item found with custom_id: {target_custom_id}")
    else:
        print("Data is not a list")
# Out:
# Found item with custom_id: 203288af-ef39-41da-bff6-5184ad83b951
# Item contents:
# {
#   "custom_id": "203288af-ef39-41da-bff6-5184ad83b951",
#   "verification_response": ""
# }

# %%
# load first row of JSONL file from this path with keys

import json

# Load first row of the JSONL file
import pandas as pd

file_path = "/mnt/fast10/brandon/mmr_rollout_data/flattened_rollout_files/CLEVR_10k_flattened.jsonl"
df = pd.read_json(file_path, lines=True)
print(f"Number of rows: {len(df)}")

with open(file_path, 'r') as f:
    first_line = f.readline().strip()
    if first_line:
        first_row = json.loads(first_line)
        print("Keys in first row:")
        for key in first_row.keys():
            print(f"  - {key}")
        print("First row values:")
        for key, value in first_row.items():
            print(f"  {key}: {value}")
        # print(first_row["conversations"])
        # print(first_row[""])
        print(f"\nTotal keys: {len(first_row.keys())}")
    else:
        print("File is empty")
# Out:
# Number of rows: 59992
# Keys in first row:
#   - image
#   - question
#   - answer
#   - uid
#   - image_path
#   - response
#   - steps_with_score
# First row values:
#   image: MMPR-v1.2-prompts/correctness_images/CLEVR_math_en_20240402_extracted/CLEVR_v1.0/images/train/CLEVR_train_012936.png
#   question: You are an advanced visual reasoning AI specialized in analyzing images. Your task is to examine images containing simple geometric shapes and answer questions about their attributes and relationships.
#
# You will be provided with:
#
# 1. An image containing geometric shapes (cubes, spheres, and cylinders) with various attributes (colors, sizes, materials) and spatial relationships.
# 2. A question about the contents of the image.
#
# Here is the question you need to answer:
#
# <question>
# Add 2 large cyan shiny things. How many objects exist?
# Answer the question using a single word or phrase.
# </question>
#
# Please follow these steps to complete the task:
#
# 1. Carefully examine the image, paying attention to:
#    - Types of shapes present (cubes, spheres, cylinders)
#    - Attributes of each shape (color, size, material)
#    - Spatial relationships between shapes
#
# 2. Read and understand the question, identifying the type of reasoning required (counting, existence, comparison, or attribute query).
#
# 3. Analyze the image in relation to the question, focusing on relevant shapes and attributes.
#
# 4. Formulate your answer based on your analysis.
#
# 5. Present your final answer as a single integer in a LaTeX-formatted box using this format:
#    <correct_answer>
#    $\boxed{integer}$
#    </correct_answer>
#
# Your task is to:
# - Under the [Visual Elements] section, list out your step-by-step perception of the visual elements in the image. Be thorough but concise. Wrap each step in <step_1>, <step_2>, ... tags.
# - Under the [Reasoning] section, explain your step-by-step reasoning process. This should include your analysis, interpretation, and how you arrived at the answer. Provide a clear justification of how you derived the answer from the data presented. Wrap each step in <step_1>, <step_2>, ... tags.
# - Present your final answer using the LaTeX-formatted box in `<correct_answer>` tags.
#
# It is crucial that your solution contains these sections in the exact format described below:
#
# ```
# [Visual Elements]
# <step_1>
# ...(Step 1 of step-by-step perception)...
# </step_1>
# <step_2>
# ...(Step 2 of step-by-step perception)...
# </step_2>
# ...
# <step_n>
# ...(Step n of step-by-step perception)...
# </step_n>
#
# [Reasoning]
# <step_1>
# ...(Step 1 of step-by-step reasoning)...
# </step_1>
# <step_2>
# ...(Step 2 of step-by-step reasoning)...
# </step_2>
# ...
# <step_m>
# ...(Step m of step-by-step reasoning)...
# </step_m>
#
# <correct_answer>
# $\boxed{integer}$
# </correct_answer>
# ```
#
# Remember to:
# - List all visual observations in the [Visual Elements] section using numbered <step_1>, <step_2>, ... tags.
# - Explain your complete reasoning process in the [Reasoning] section using numbered <step_1>, <step_2>, ... tags.
# - Provide only an integer answer in the <correct_answer> section using the $\boxed{integer}$ format
# - Include only these three sections in your response, with no additional commentary.
#   answer: 10
#   uid: 124c88e8-4a6d-4677-9539-f50df2e2c0a5
#   image_path: /data/users/brandon/ob1-projects/InternVL/internvl_chat/rollout_generation/preprocessed_prompts/preprocessing_scripts/CLEVR-MATH/subset_images/CLEVR_train_012936.png
#   response: [Visual Elements]
# <step_1>
# There are eight objects in the image: five cylinders, one cube, and two spheres.
# </step_1>
# <step_2>
# Attributes by object:
# - Leftmost sphere: small, blue, shiny/metallic.
# - Front center-left cylinder: large, green, matte.
# - Front center-right cylinder: large, brown, matte.
# - Front center cube: large, cyan, matte.
# - Rear left cylinder: large, cyan, shiny.
# - Rear center-right cylinder: large, purple, shiny.
# - Rearmost cylinder: small, dark gray, shiny.
# - Rightmost sphere: small, yellow, matte.
# </step_2>
# <step_3>
# Materials: Some objects are shiny/metallic (blue sphere, cyan and purple cylinders, small dark gray cylinder), others are matte.
# </step_3>
# <step_4>
# Colors include cyan, blue, green, brown, purple, yellow, and gray.
# </step_4>
# <step_5>
# Sizes: Most objects are large except the two spheres and the small dark gray cylinder.
# </step_5>
#
# [Reasoning]
# <step_1>
# Count the current total objects: 1 blue sphere + 1 yellow sphere + 1 cyan cube + 1 green cylinder + 1 brown cylinder + 1 cyan shiny cylinder + 1 purple shiny cylinder + 1 small gray shiny cylinder = 8 objects.
# </step_1>
# <step_2>
# Determine how many "large cyan shiny things" are currently in the image. The rear left cylinder is large, cyan, and shiny. There is only one such object.
# </step_2>
# <step_3>
# The question asks to "Add 2 large cyan shiny things." So, add 2 additional large cyan shiny objects to the scene.
# </step_3>
# <step_4>
# Recalculate the total number of objects: 8 original objects + 2 new large cyan shiny objects = 10 objects.
# </step_4>
#
# <correct_answer>
# $\boxed{10}$
# </correct_answer>
#   steps_with_score: [{'step': 'There are eight objects in the image: five cylinders, one cube, and two spheres.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Attributes by object:\n- Leftmost sphere: small, blue, shiny/metallic.\n- Front center-left cylinder: large, green, matte.\n- Front center-right cylinder: large, brown, matte.\n- Front center cube: large, cyan, matte.\n- Rear left cylinder: large, cyan, shiny.\n- Rear center-right cylinder: large, purple, shiny.\n- Rearmost cylinder: small, dark gray, shiny.\n- Rightmost sphere: small, yellow, matte.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Materials: Some objects are shiny/metallic (blue sphere, cyan and purple cylinders, small dark gray cylinder), others are matte.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Colors include cyan, blue, green, brown, purple, yellow, and gray.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Sizes: Most objects are large except the two spheres and the small dark gray cylinder.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Count the current total objects: 1 blue sphere + 1 yellow sphere + 1 cyan cube + 1 green cylinder + 1 brown cylinder + 1 cyan shiny cylinder + 1 purple shiny cylinder + 1 small gray shiny cylinder = 8 objects.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Determine how many "large cyan shiny things" are currently in the image. The rear left cylinder is large, cyan, and shiny. There is only one such object.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'The question asks to "Add 2 large cyan shiny things." So, add 2 additional large cyan shiny objects to the scene.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}, {'step': 'Recalculate the total number of objects: 8 original objects + 2 new large cyan shiny objects = 10 objects.', 'score': 1.0, 'num_mc_correct': 16, 'num_mc_total': 16}]
#
# Total keys: 7
